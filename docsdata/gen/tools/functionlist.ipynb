# %%
calls = [
    "preview_focus_content", 
    "preview_save_current_frame", 
    "preview_save_all_current_frame", 
    "preview_preview_window", 
    "preview_toggle_grid", 
    "preview_pan", 
    "preview_zoom", 
    "undo", 
    "redo", 
    "fullscreen", 
    "render_all", 
    "project_close", 
    "theme_reload", 
    "inspector_copy_prop", 
    "inspector_paste_prop", 
    "inspector_toggle_animation", 
    "inspector_color_pick", 
    "animation_play_pause", 
    "animation_resume", 
    "animation_first_frame", 
    "animation_last_frame", 
    "animation_next_frame", 
    "animation_prev_frame", 
    "animation_delete_key", 
    "animation_duplicate", 
    "animation_copy", 
    "animation_paste", 
    "append", 
    "new", 
    "save", 
    "graph_add_node", 
    "graph_focus_content", 
    "graph_preview_focus", 
    "graph_preview_window", 
    "graph_import_image", 
    "graph_import_image_array", 
    "graph_add_number", 
    "graph_add_vec2", 
    "graph_add_vec3", 
    "graph_add_vec4", 
    "graph_add_transform", 
    "graph_select_all", 
    "graph_toggle_grid", 
    "graph_toggle_preview", 
    "graph_toggle_render", 
    "graph_export", 
    "graph_blend", 
    "graph_compose", 
    "graph_array", 
    "graph_group", 
    "graph_ungroup", 
    "graph_canvas", 
    "graph_canvas_blend", 
    "graph_frame", 
    "graph_delete_break", 
    "graph_delete_merge", 
    "graph_duplicate", 
    "graph_copy", 
    "graph_paste", 
    "graph_pan", 
    "graph_zoom", 
    "load", 
    "close", 
    "exit", 
]

# %%
for c in calls:
    print(f"""<br>
<h3><span class="inline-code">{c}</span></h3>
<br>
<p>{c} description</p>
<br>""")
# Out:
# <br>
# <h3><span class="inline-code">preview_focus_content</span></h3>
# <br>
# <p>preview_focus_content description</p>
# <br>
# <br>
# <h3><span class="inline-code">preview_save_current_frame</span></h3>
# <br>
# <p>preview_save_current_frame description</p>
# <br>
# <br>
# <h3><span class="inline-code">preview_save_all_current_frame</span></h3>
# <br>
# <p>preview_save_all_current_frame description</p>
# <br>
# <br>
# <h3><span class="inline-code">preview_preview_window</span></h3>
# <br>
# <p>preview_preview_window description</p>
# <br>
# <br>
# <h3><span class="inline-code">preview_toggle_grid</span></h3>
# <br>
# <p>preview_toggle_grid description</p>
# <br>
# <br>
# <h3><span class="inline-code">preview_pan</span></h3>
# <br>
# <p>preview_pan description</p>
# <br>
# <br>
# <h3><span class="inline-code">preview_zoom</span></h3>
# <br>
# <p>preview_zoom description</p>
# <br>
# <br>
# <h3><span class="inline-code">undo</span></h3>
# <br>
# <p>undo description</p>
# <br>
# ...
