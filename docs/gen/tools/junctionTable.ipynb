# %%
data = [
    "integer", 
    "float", 
    "boolean", 
    "color", 
    "surface", 
            
    "path", 
    "curve", 
    "text", 
    "object", 
    "node", 
    "d3object", 
            
    "any", 
            
    "pathnode", 
    "particle", 
    "rigid", 
    "sdomain", 
    "struct", 
    "strands", 
    "mesh", 
    "trigger", 
    "atlas",
            
    "d3vertex", 
    "gradient", 
    "armature", 
    "buffer", 
            
    "pbBox", 
            
    "d3Mesh", 
    "d3Light", 
    "d3Camera", 
    "d3Scene", 
    "d3Material", 
            
    "dynaSurface", 
    "PCXnode", 
            
    "audioBit", 
    "fDomain",
            
    "action", 
]

# %%
for d in data:
    print(f"""    <tr>
        <td>{d.title()}</td>
        <td><img src="/src/images/3_nodes/junction/{d}.png" alt=""></td>
        <td></td>
        <td></td>
    </tr>""")
# Out:
#     <tr>
#         <td>Integer</td>
#         <td><img src="/src/images/3_nodes/junction/integer.png" alt=""></td>
#         <td></td>
#         <td></td>
#     </tr>
#     <tr>
#         <td>Float</td>
#         <td><img src="/src/images/3_nodes/junction/float.png" alt=""></td>
#         <td></td>
#         <td></td>
#     </tr>
#     <tr>
#         <td>Boolean</td>
#         <td><img src="/src/images/3_nodes/junction/boolean.png" alt=""></td>
#         <td></td>
#         <td></td>
#     </tr>
#     <tr>
#         <td>Color</td>
#         <td><img src="/src/images/3_nodes/junction/color.png" alt=""></td>
#         <td></td>
#         <td></td>
#     </tr>
#     <tr>
#         <td>Surface</td>
#         <td><img src="/src/images/3_nodes/junction/surface.png" alt=""></td>
#         <td></td>
#         <td></td>
#     </tr>
#     <tr>
#         <td>Path</td>
#         <td><img src="/src/images/3_nodes/junction/path.png" alt=""></td>
#         <td></td>
#         <td></td>
#     </tr>
# ...
